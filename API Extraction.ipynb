# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     227.544
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     265.375
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      93.968
# 3  The true story of how businessman Oskar Schind...   1993-12-15     146.538
# 4  The defense and the prosecution have rested an...   1957-04-10      76.462
#
#    vote_average  vote_count
# 0         8.705       26561
# 1         8.691       20161
# 2         8.575       12166
# 3         8.565       15573
# 4         8.543        8417

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                              title  \
# 0        278           The Shawshank Redemption
# 1        238                      The Godfather
# 2        240              The Godfather Part II
# 3        424                   Schindler's List
# 4        389                       12 Angry Men
# ...      ...                                ...
# 6095   10191           How to Train Your Dragon
# 6096    3078              It Happened One Night
# 6097      93                Anatomy of a Murder
# 6098  530254  The Witch: Part 1. The Subversion
# 6099  152742                     The Best Offer
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 6095  As the son of a Viking leader on the cusp of m...   2010-03-18
# 6096  A rogue reporter trailing a runaway heiress fo...   1934-02-22
# 6097  Semi-retired Michigan lawyer Paul Biegler take...   1959-01-07
# 6098  Ja-yoon is a high school student who struggles...   2018-06-27
# 6099  Virgil Oldman is a world renowned antiques exp...   2013-01-01
#
#       popularity  vote_average  vote_count
# 0        227.544         8.705       26561
# 1        265.375         8.691       20161
# 2         93.968         8.575       12166
# 3        146.538         8.565       15573
# 4         76.462         8.543        8417
# ...          ...           ...         ...
# 6095      94.706         7.829       12750
# 6096      24.156         7.829        1208
# 6097      20.642         7.829         937
# 6098      51.953         7.828         527
# 6099      25.052         7.828        2782
#
# [6100 rows x 7 columns]

# %%
df.shape
# Out:
# (5560, 7)

# %%
df.to_csv('movies.csv')
